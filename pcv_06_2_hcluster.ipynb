# %% [markdown]
# <a href="https://colab.research.google.com/github/Adachi-Yoshitaka/clustering/blob/main/pcv_06_2_hcluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 実践コンピュータビジョン
# # 6章 画像のクラスタリング
# ## 6.2 階層クラスタリング
# ### 6.2.1 画像のクラスタリング
# テキストp.141
#
# 階層クラスタリングに用いるクラスClusterNodeをhcluster.pyに実装する。<br>
# hcluster.pyの内容については省略。

# %%
# !git clone --recursive https://github.com/Adachi-Yoshitaka/clustering
# Out:
# Mounted at /content/drive

# %%
# %cd /content/clustering
# Out:
# /content/drive/My Drive/pcv_note/chap6

# %%
import numpy as np
from numpy import random
from scipy import linalg
from PIL import Image
import matplotlib.pyplot as plt
from scipy.cluster import vq
# %matplotlib inline

# %%
import os
import hcluster

# %%
# 画像のリストを作成する
path = 'flickr-sunsets-small/'
imlist = [os.path.join(path,f) for f in os.listdir(path)
          if f.endswith('.jpg')]
len(imlist)
# Out:
# 100

# %%
# 特徴量ベクトルを抽出する（色チャンネルに8つのビン）
features = np.zeros([len(imlist), 512])
for i,f in enumerate(imlist):
    im = np.array(Image.open(f))

    # 多次元ヒストグラム
    h,edges = np.histogramdd(im.reshape(-1,3),8,normed=True,
                        range=[(0,255),(0,255),(0,255)])
    features[i] = h.flatten()

# %%
# 階層クラスタリングを行う
tree = hcluster.hcluster(features)

# %%
# 階層クラスタを示す系統図を表示する
hcluster.draw_dendrogram(tree,imlist,filename='sunset_dendrogram.jpg')

# %%
# 任意の閾値についてクラスタを可視化する
clusters = tree.extract_clusters(0.23*tree.distance)
len(clusters)
# Out:
# 79

# %%
# 3要素以上のクラスタの画像を描画する
i = 0
nbr_e_list = []
for c in clusters:
    elements = c.get_cluster_elements()
    nbr_elements = len(elements)
    nbr_e_list.append(nbr_elements)
    if nbr_elements>2:
        plt.figure(figsize=(15,12))
        for p in range(np.minimum(nbr_elements,20)):
            plt.subplot(4,5,p+1)
            im = np.array(Image.open(imlist[elements[p]]))
            plt.imshow(im)
            tname = 'Cluster: '+ str(i+1) + ', Image: ' + str( p + 1) 
            plt.title(tname)
            plt.axis('off')
        i+=1
plt.show()
